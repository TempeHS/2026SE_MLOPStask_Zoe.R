# %% [markdown]
# [Home](../../README.md)
#
# ### Data Wrangling
#
# This is a demonstration of data wrangling using [Pandas](https://pandas.pydata.org/) the library for data analysis and manipulation.
#
# This Jupyter Notepad demonstrates different processes you can apply to your data to prepare it for feature engineering and model training. For this demonstration we will wrangle the diabetes data set you previewed in the last Jupyter Notebook.
#
# > [!Note]
# > None of these processes are destructive to the source CSV as long as you save the modified data to a new CSV.

# %% [markdown]
# #### Load the required dependencies

# %%
# Import frameworks
import pandas as pd

# %% [markdown]
# ####  Store the data as a local variable
#
# The data frame is a Pandas object that structures your tabular data into an appropriate format. It loads the complete data in memory so it is now ready for preprocessing.

# %%
data_frame = pd.read_csv("vgsales.csv")

# %% [markdown]
# #### Dealing with null values
#
# Null values during data analysis can cause runtime errors and unexpected results. It is important to identify null values and deal with them appropriately before training a model.
#
# The `isnull().sum()` method call returns the null values in any column.

# %%
data_frame.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %% [markdown]
# If you have null data there are many ways to deal with the empty/null values. These are the two most common approaches.
# 1. Remove any row with a null value with a `dropna()` method call.
# 2. Replace missing values with another value with a `fillna()` method call. Generally, we use mean value for numerical columns because it may cause minimal changes in your mathematical analysis while maintaining the original size of the data.
#
# Students should reflect why this example removes the null 'SEX' but replacing the mean 'Target'?

# %%
# Remove Null values
data_frame = data_frame.dropna(subset=['Year', 'Publisher'])
data_frame.isnull().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %% [markdown]
# My data had no numerical null values, so there weren't any that I needed to/could replace with the mean

# %% [markdown]
# #### Remove Duplicates
#
# Duplicate data can have detrimental effects on your machine learning models and outcomes, such as reducing data diversity and representativeness, which can lead to overfitting or biased models.
#
# The `duplicated().sum()` method call returns the count of duplicate rows in the data frame.

# %%
data_frame.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# The `drop_duplicates()` method call can be then stored back onto the data_frame variable removing the duplicates.

# %%
#data_frame = data_frame.drop_duplicates()
#data_frame.duplicated().sum()

# %% [markdown]
# #### Replace data
#
# We can run a lambda function on a column to modify its values. For a simple example, let’s convert the Sex to lowercase. To run a function over a complete column, we can use the apply method which iterates over each row and modifies the values.

# %%
#Unnecessary, as there isn't any difference in capitalisation

#data_frame["Genre"] = data_frame["Genre"].apply(lambda x: x.lower())
#data_frame["Genre"].head()

# %% [markdown]
# We can check that there are no data entry errors by the `unique()` method call.

# %%
data_frame['Genre'].unique()
# Out:
# <StringArray>
# [      'Sports',     'Platform',       'Racing', 'Role-Playing',
#        'Puzzle',         'Misc',      'Shooter',   'Simulation',
#        'Action',     'Fighting',    'Adventure',     'Strategy']
# Length: 12, dtype: str

# %%
data_frame['Publisher'].unique()
data_frame["Publisher"] = data_frame["Publisher"].apply(
    lambda category: ('AAA' if category == "Microsoft Game Studios" 
    else 'AAA' if category == "Nintendo"
    else 'AAA' if category == "Sony Computer Entertainment"
    else 'AAA' if category == "Sony Computer Entertainment Europe"
    else 'AAA' if category == "Electronic Arts"
    else 'AAA' if category == "Ubisoft"
    else 'AAA' if category == "Activision"
    else 'AAA' if category == "Sega"
    else 'AAA' if category == "Take-Two Interactive"
    else 'AAA' if category == "Capcom"
    else 'AAA' if category == "Bethesda Softworks"
    else 'AAA' if category == "Namco Bandai Games"
    else 'AAA' if category == "From Software"
    else 'AAA' if category == "Paradox Interactive"
    else 'AAA' if category == "Aspyr"
    else 'AAA' if category == "Konami Digital Entertainment"
    else 'AAA' if category == "Warner Bros. Interactive Entertainment"
    else 'AAA' if category == "Focus Home Interactive"
    else 'AAA' if category == "Bohemia Interactive"
    else 'AAA' if category == "Deep Silver"
    else 'AAA' if category == "Team17"
    else 'AAA' if category == "Activision Blizzard"
    else 'AAA' if category == "Valve Software"
    else 'AA' if category == "Square Enix" 
    else 'AA' if category == "THQ" 
    else 'AA' if category == "Devolver Digital" 
    else 'AA' if category == "Tecmo Koei" 
    else 'AA' if category == "Wargaming.net" 
    else 'AA' if category == "Hello Games" 
    else 'AA' if category == "Crystal Dynamics" 
    else 'AA' if category == "Tripwire Interactive" 
    else 'AA' if category == "Rebellion Developments" 
    else 'AA' if category == "Cygames" 
    else 'AA' if category == "Funcom" 
    else 'AA' if category == "Nexon" 
    else 'AA' if category == "SCS Software" 
    else 'AA' if category == "Daedalic" 
    else 'AA' if category == "Disney Interactive Studios" 
    else 'AA' if category == "Xseed Games" 
    else 'AA' if category == "LucasArts" 
    else 'AA' if category == "Marvelous Interactive" 
    else 'AA' if category == "Eidos Interactive" 
    else 'AA' if category == "Astragon" 
    else 'AA' if category == "Slitherine Software" 
    else 'AA' if category == "Spike" 
    else 'AA' if category == "Kalypso Media" 
    else 'AA' if category == "Arc System Works" 
    else 'AA' if category == "Gameloft" 
    else 'AA' if category == "NCSoft" 
    else 'AA' if category == "Milestone S.r.l." 
    else 'AA' if category == "Aerosoft" 
    else 'AA' if category == "D3Publisher" 
    else 'AA' if category == "inXile Entertainment" 
    else 'Indie')
)
data_frame['Publisher'].unique()
# Out:
# <StringArray>
# ['AAA', 'Indie', 'AA']
# Length: 3, dtype: str

# %%
data_frame["Platform"].unique()
# Out:
# <StringArray>
# [ 'Wii',  'NES',   'GB',   'DS', 'X360',  'PS3',  'PS2', 'SNES',  'GBA',
#   '3DS',  'PS4',  'N64',   'PS',   'XB',   'PC', '2600',  'PSP', 'XOne',
#    'GC', 'WiiU',  'GEN',   'DC',  'PSV',  'SAT',  'SCD',   'WS',   'NG',
#  'TG16',  '3DO',   'GG', 'PCFX']
# Length: 31, dtype: str

# %%
#No unnecessary unique values

#data_frame['SEX'] = data_frame['SEX'].apply(lambda gender: 'male' if gender.lower() == 'male' else 'female')
#data_frame['SEX'].unique()

# %% [markdown]
# #### Remove outliers
#
# Outliers can skew your analysis on numerical columns, and it is important to remove them. We can use the 25th and 75th quartile on numerical data, to get the inter-quartile range. This allows us to estimate an acceptable range, and we can then filter out any values outside this range. Mathematically, outliers are values occurring outside 1.5 times the interquartile range (IQR) from the first quartile (Q1) or third quartile (Q3).

# %%
print(data_frame['Global_Sales'].describe())
outlierlimit = data_frame["Global_Sales"].quantile(0.9995).round(2)
print(f"Outliers are include any number of global sales above {outlierlimit}M")
# Out:
# count    16291.000000
# mean         0.540910
# std          1.567345
# min          0.010000
# 25%          0.060000
# 50%          0.170000
# 75%          0.480000
# max         82.740000
# Name: Global_Sales, dtype: float64
# Outliers are include any number of global sales above 28.58M

# %%
# Filter global sales within the acceptable range
data_frame = data_frame[(data_frame['Global_Sales'] <= outlierlimit)]
print(data_frame['Global_Sales'].describe())
# Out:
# count    16282.000000
# mean         0.520261
# std          1.241099
# min          0.010000
# 25%          0.060000
# 50%          0.170000
# 75%          0.480000
# max         28.310000
# Name: Global_Sales, dtype: float64

# %% [markdown]
# #### Scaling features to a common range
#
# Scaling the features makes it easier for machine learning algorithms to find the optimal solution, as the different scales of the features do not influence them.

# %%
#sighhhhhhh ok i'll scale ts

scale_feature = 'Global_Sales'

#the minimum value with space for outliers
MIN_GS = 0

#the maximum value with space for outliers
MAX_GS = 30

#scale features
data_frame[scale_feature] = [(X - MIN_GS) / (MAX_GS - MIN_GS) for X in data_frame[scale_feature]]

data_frame.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16282.000000  16282.000000  16282.000000  16282.000000  16282.000000
# mean    8294.769930   2006.408242      0.254945      0.142093      0.076038
# std     4790.017435      5.829358      0.648120      0.415174      0.283736
# min       10.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4139.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8296.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12441.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     26.930000     11.000000      7.200000
#
#         Other_Sales  Global_Sales
# count  16282.000000  16282.000000
# mean       0.046912      0.017342
# std        0.171004      0.041370
# min        0.000000      0.000333
# 25%        0.000000      0.002000
# 50%        0.010000      0.005667
# 75%        0.040000      0.016000
# ...

# %% [markdown]
# > [!important]
# > You need to save the calculations for each dataset you scale for scaling new values for prediction. Use [2.1.2.data.records.md](2.1.2.data.records.md) to record this information.

# %% [markdown]
# A short block of code to test scaling the features from 0-1 back to the original range - which will be used when the machine produces results.

# %%
#denormalised_data = scale_feature

#data_frame[denormalised_data] = [(X + MIN_GS) * (MAX_GS + MIN_GS) for X in data_frame[scale_feature]]
#data_frame.describe()

# %% [markdown]
# #### Save the wrangled data to CSV

# %%
data_frame.to_csv('../2.2.Feature_Engineering/wrangled_data_BETTER.csv', index=False)
