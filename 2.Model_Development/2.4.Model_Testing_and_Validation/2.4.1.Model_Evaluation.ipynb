# %% [markdown]
# [Home](../../README.md)
#
# ### Model Evaluation
#
# This is a demonstration of evaluating a model.

# %% [markdown]
# #### Step 1
#
# Load the required dependencies.

# %%
# Import frameworks
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('../../style_Matplotlib_charts.mplstyle')
from sklearn.linear_model import LinearRegression
import sklearn
import pickle

# %% [markdown]
# ####  Step 2
#
# Load the model for testing

# %%
filename = 'test_1.sav'
model_A = pickle.load(open(filename, 'rb'))

# %% [markdown]
# (Optional) Load a second model if you want to do comparative testing

# %%
#filename = 'my_saved_model_v1.sav'
#model_B = pickle.load(open(filename, 'rb'))

# %% [markdown]
# ####  Step 3
# Open and parse the test data CSV file and store the data as variable array data objects.

# %%
x_col = ['Platform', 'Genre']
testing_data = pd.read_csv('AAA_testing_data.csv')
x_test = np.array(testing_data[x_col]).reshape(-1,1)
y_test = np.array(testing_data['Global_Sales'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 x_col = ['Platform', 'Genre']
# ----> 2 testing_data = pd.read_csv('AAA_testing_data.csv')
#       3 x_test = np.array(testing_data[x_col]).reshape(-1,1)
#       4 y_test = np.array(testing_data['Global_Sales'])
#
# File ~/.local/lib/python3.11/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~/.local/lib/python3.11/site-packages/pandas/io/parsers/readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~/.local/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~/.local/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~/.local/lib/python3.11/site-packages/pandas/io/common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     921 elif isinstance(handle, str):
#     922     # Check whether the filename is to be opened in binary mode.
#     923     # Binary mode does not support 'encoding' and 'newline'.
#     924     if ioargs.encoding and "b" not in ioargs.mode:
#     925         # Encoding
# --> 926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#     929             encoding=ioargs.encoding,
#     930             errors=errors,
#     931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
#     935         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'AAA_testing_data.csv'

# %% [markdown]
# #### Step 5
#
# Plot the test data features, targets and linear regression model to visually evaluate the model.

# %%
y_pred = model_A.predict(x_test)
plt.scatter(x_test, y_pred)
plt.scatter(x_test, y_test, marker='x', c='r')
plt.title("NESA Course Specifications Data")
plt.ylabel(f'Testing {x_col}')
plt.xlabel(f'Testing Target')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 y_pred = model_A.predict(x_test)
#       2 plt.scatter(x_test, y_pred)
#       3 plt.scatter(x_test, y_test, marker='x', c='r')
#
# File ~/.local/lib/python3.11/site-packages/sklearn/linear_model/_base.py:311, in LinearModel.predict(self, X)
#     297 def predict(self, X):
#     298     """
#     299     Predict using the linear model.
#     300
#    (...)    309         Returns predicted values.
#     310     """
# --> 311     return self._decision_function(X)
#
# File ~/.local/lib/python3.11/site-packages/sklearn/linear_model/_base.py:290, in LinearModel._decision_function(self, X)
#     287 def _decision_function(self, X):
#     288     check_is_fitted(self)
# --> 290     X = validate_data(self, X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     291     coef_ = self.coef_
#     292     if coef_.ndim == 1:
#
# File ~/.local/lib/python3.11/site-packages/sklearn/utils/validation.py:2923, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2920     out = X, y
#    2922 if not no_val_X and check_params.get("ensure_2d", True):
# -> 2923     _check_n_features(_estimator, X, reset=reset)
#    2925 return out
#
# File ~/.local/lib/python3.11/site-packages/sklearn/utils/validation.py:2787, in _check_n_features(estimator, X, reset)
#    2784     return
#    2786 if n_features != estimator.n_features_in_:
# -> 2787     raise ValueError(
#    2788         f"X has {n_features} features, but {estimator.__class__.__name__} "
#    2789         f"is expecting {estimator.n_features_in_} features as input."
#    2790     )
#
# ValueError: X has 2 features, but LinearRegression is expecting 65 features as input.

# %% [markdown]
# #### Step 6
#
# Use the 'score' method of the `LinearRegression` class to return a score based evaluation of the models accuracy or performance.

# %%
test_score = model_A.score(x_test, y_test)
print(f'Training data score: {test_score}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 test_score = model_A.score(x_test, y_test)
#       2 print(f'Training data score: {test_score}')
#
# File ~/.local/lib/python3.11/site-packages/sklearn/base.py:653, in RegressorMixin.score(self, X, y, sample_weight)
#     611 """Return :ref:`coefficient of determination <r2_score>` on test data.
#     612
#     613 The coefficient of determination, :math:`R^2`, is defined as
#    (...)    648 :class:`~sklearn.multioutput.MultiOutputRegressor`).
#     649 """
#     651 from sklearn.metrics import r2_score
# --> 653 y_pred = self.predict(X)
#     654 return r2_score(y, y_pred, sample_weight=sample_weight)
#
# File ~/.local/lib/python3.11/site-packages/sklearn/linear_model/_base.py:311, in LinearModel.predict(self, X)
#     297 def predict(self, X):
#     298     """
#     299     Predict using the linear model.
#     300
#    (...)    309         Returns predicted values.
#     310     """
# --> 311     return self._decision_function(X)
#
# File ~/.local/lib/python3.11/site-packages/sklearn/linear_model/_base.py:290, in LinearModel._decision_function(self, X)
#     287 def _decision_function(self, X):
#     288     check_is_fitted(self)
# --> 290     X = validate_data(self, X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     291     coef_ = self.coef_
#     292     if coef_.ndim == 1:
#
# File ~/.local/lib/python3.11/site-packages/sklearn/utils/validation.py:2923, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2920     out = X, y
#    2922 if not no_val_X and check_params.get("ensure_2d", True):
# -> 2923     _check_n_features(_estimator, X, reset=reset)
#    2925 return out
#
# File ~/.local/lib/python3.11/site-packages/sklearn/utils/validation.py:2787, in _check_n_features(estimator, X, reset)
#    2784     return
#    2786 if n_features != estimator.n_features_in_:
# -> 2787     raise ValueError(
#    2788         f"X has {n_features} features, but {estimator.__class__.__name__} "
#    2789         f"is expecting {estimator.n_features_in_} features as input."
#    2790     )
#
# ValueError: X has 1 features, but LinearRegression is expecting 65 features as input.

# %% [markdown]
# #### Step 7
#
# Manually calculate and evaluate the 'loss' and 'cost' of the model using the test data.

# %%
table = pd.DataFrame({
    testing_data.columns[0]: x_test.flatten(),  # Flatten x for easy display
    testing_data.columns[1]: y_test,
    'Predicted result':model_A.predict(x_test),
    'Loss' : abs(model_A.predict(x_test).round(2) - y_test)**2
})
print(table)
cost = 1 / (2 * table.shape[0]) * table['Loss'].sum()

print(f"The cost or average loss of this model is {cost}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 table = pd.DataFrame({
#       2     testing_data.columns[0]: x_test.flatten(),  # Flatten x for easy display
#       3     testing_data.columns[1]: y_test,
#       4     'Predicted result':model_A.predict(x_test),
#       5     'Loss' : abs(model_A.predict(x_test).round(2) - y_test)**2
#       6 })
#       7 print(table)
#       8 cost = 1 / (2 * table.shape[0]) * table['Loss'].sum()
#
# NameError: name 'pd' is not defined

# %% [markdown]
# You may want to do some manual predictions to understand your model.

# %%
print(model_A.predict([[0.1]]))
print(model_A.predict([[1]]))

# %% [markdown]
# #### Step 8
#
# Evaluate the X axis intercept and gradient or coefficient of your model by using the getter methods to return the intercept and coefficient from my_model() object.

# %%
print(f'X Axis intercept: {model_A.intercept_}')
print(f'Coefficient: {model_A.coef_}')

# %% [markdown]
# #### Step 9. Multiple Variable Linear Regression
#
# You should be able to understand the code snippets with less guidelines.

# %%
filename = 'my_saved_model_v2.sav'
model_C = pickle.load(open(filename, 'rb'))

# %%
mx_col = ['BMI','BP','FDR']
testing_data = pd.read_csv('2.4.1.testing_data.csv')
mx_test = np.array(testing_data[mx_col]).reshape(-1,1)
my_test = np.array(testing_data['Target'])

# %%
my_pred = model_C.predict(mx_test)

# plot predictions and targets vs original features    
fig,ax=plt.subplots(1,len(mx_col),figsize=(12,3),sharey=True)
for i in range(len(ax)):
    ax[i].scatter(mx_test[:,i],my_test, label = 'target')
    ax[i].set_xlabel(mx_col[i])
    ax[i].scatter(mx_test[:,i],my_pred,color="orange", label = 'predict')
    ax[i].set_ylabel("Target"); ax[i].legend();
fig.suptitle("Diabetes Disease Progress")
plt.show()

# %%
test_score = model_C.score(mx_test, my_test)
print(f'Training data score: {test_score}')

# %%
print(model_C.predict([[0.1,0.1,0.1]]))
print(model_C.predict([[1,0.5,1]]))

# %%
data = {col: mx_test[:, i] for i, col in enumerate(mx_col)}
data['Target'] = my_test
data['Predicted result'] = model_C.predict(mx_test)
data['Loss'] = abs(model_C.predict(mx_test).round(2) - my_test)**2
table = pd.DataFrame(data)

cost = 1 / (2 * table.shape[0]) * table['Loss'].sum()
print(f"The cost or average loss of this model is {cost}")

print(table)

# %%
print(f'X Axis intercept: {model_C.intercept_}')
print(f'Coefficient: {model_C.coef_}')

# %% [markdown]
# #### Step 10. Polynomial Linear Regression
#
# You should be able to understand the code snippets with less guidelines.

# %%
model_filename = 'my_saved_model_v3.sav'
poly_filename = 'my_saved_poly_v3.pkl'

model_D = pickle.load(open(model_filename, 'rb'))
poly = pickle.load(open(poly_filename, 'rb'))

# %%
mx_col = ['BMI']
testing_data = pd.read_csv('2.4.1.testing_data.csv')
mx_test = np.array(testing_data[mx_col])
my_test = np.array(testing_data['Target'])

# %%
poly_features = poly.fit_transform(mx_test)

# %%
y_pred = model_D.predict(poly_features)

plt.scatter(x_test, y_pred)
plt.scatter(x_test, y_test, marker='x', c='r')
plt.title("NESA Course Specifications Data")
plt.ylabel(f'Testing {x_col}')
plt.xlabel(f'Testing Target')
plt.show()

# %%
test_score = model_D.score(poly_features, my_test)
print(f'Training data score: {test_score}')

# %%
new_poly_feature = poly.fit_transform([[0.1]])
print(model_D.predict(new_poly_feature))

# %%
data = {col: mx_test[:, i] for i, col in enumerate(mx_col)}
data['Target'] = my_test
data['Predicted result'] = model_D.predict(poly_features)
data['Loss'] = abs(model_D.predict(poly_features).round(2) - my_test)**2
table = pd.DataFrame(data)

cost = 1 / (2 * table.shape[0]) * table['Loss'].sum()
print(f"The cost or average loss of this model is {cost}")

print(table)

# %% [markdown]
# #### Step 11
#
# When your model is ready for operations, move it to the [3.Operations\3.1.Deploy_Model](\3.Operations\3.1.Deploy_Model) folder.
