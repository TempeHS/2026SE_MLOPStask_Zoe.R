# %% [markdown]
# [Home](../../README.md)
#
# ### Model Training
#
# We will take the real world data set and split it into two. The training set will be used for training the model and the testing set will be used to test the model.

# %% [markdown]
# #### Step 1
#
# Load the required dependencies:

# %%
# Import frameworks
import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# ####  Step 2
# - Open the [CSV](3.course_specifications_data.csv) file with [Pandas](https://pandas.pydata.org/)
# - Split the data set into a training and testing data set that will be saved as separate CSV files for easy use.

# %%
# Create a data frame from the csv file
data1 = pd.read_csv('model_ready_AAA.csv')
data2 = pd.read_csv('model_ready_AA.csv')
data3 = pd.read_csv('model_ready_Indie.csv')

# Split the data into training and testing data
training_data_AAA, testing_data_AAA = train_test_split(data1, test_size=0.25)
training_data_AA, testing_data_AA = train_test_split(data1, test_size=0.25)
training_data_Indie, testing_data_Indie = train_test_split(data1, test_size=0.25)

# Save the training and testing data to csv files
training_data_AAA.to_csv('AAA_training_data.csv', index=False)
testing_data_AAA.to_csv('AAA_testing_data.csv', index=False)
training_data_AA.to_csv('AA_training_data.csv', index=False)
testing_data_AA.to_csv('AA_testing_data.csv', index=False)
training_data_Indie.to_csv('Indie_training_data.csv', index=False)
testing_data_Indie.to_csv('Indie_testing_data.csv', index=False)
