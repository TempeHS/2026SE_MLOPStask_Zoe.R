# %% [markdown]
# 5.3.26 - period 2
# - The dataset I picked has more datapoints than I initially thought, will probably have to use less for the model lest it take forever to load every time i try to run it
# - might grab a bunch of them and take the average, then see how it compares for stars with exoplanets vs stars without (need to figure out how to code this) <- that counts as data wrangling too, right?
